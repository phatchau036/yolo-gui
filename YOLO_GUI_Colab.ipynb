# %% [markdown]
# # YOLO GUI trên Google Colab
#
# Notebook này tự clone repo, cài dependency, chạy YOLO GUI và mở Cloudflare Tunnel tạm thời. Người dùng chỉ cần bấm chạy cell bên dưới, đợi link `trycloudflare.com`, rồi mở link đó để dùng giao diện web.
#
# Lưu ý: giữ cell chạy trong lúc dùng GUI. Khi dừng cell hoặc Colab ngắt runtime, link tunnel sẽ tắt.

# %%
#@title Chạy YOLO GUI
REPO_URL = "https://github.com/phatchau036/yolo-gui.git"  #@param {type:"string"}
PROJECT_DIR = "/content/yolo-gui"  #@param {type:"string"}

import os
from pathlib import Path

project_path = Path(PROJECT_DIR)
if (project_path / ".git").exists():
    os.chdir(PROJECT_DIR)
    print(f"Đang ở: {Path.cwd()}")
    # !git pull
else:
    # !git clone {REPO_URL} {PROJECT_DIR}
    os.chdir(PROJECT_DIR)
    print(f"Đang ở: {Path.cwd()}")

# !python start_colab.py
